# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import jaccard_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import jaccard_score

# %%
import os

# %%
path_image = '/application/pi/Desktop/all imp data/Unet testing/images/'
path_mask= '/application/pi/Desktop/all imp data/Unet testing/masks/'
image_list = os.listdir(path_image)
mask_list = os.listdir(path_mask)

# %%
len(mask_list)
# Out:
# 96

# %%
mask_list
# Out:
# ['trial_0_0.npy',
#  'trial_1_0.npy',
#  'trial_2_0.npy',
#  'trial_3_0.npy',
#  'trial_0_1.npy',
#  'trial_1_1.npy',
#  'trial_2_1.npy',
#  'trial_3_1.npy',
#  'trial_0_2.npy',
#  'trial_1_2.npy',
#  'trial_2_2.npy',
#  'trial_3_2.npy',
#  'trial_0_3.npy',
#  'trial_1_3.npy',
#  'trial_2_3.npy',
#  'trial_3_3.npy',
#  'trial_0_4.npy',
#  'trial_1_4.npy',
#  'trial_2_4.npy',
#  'trial_3_4.npy',
#  'trial_0_5.npy',
#  'trial_1_5.npy',
#  'trial_2_5.npy',
#  'trial_3_5.npy',
#  'trial_0_6.npy',
#  'trial_1_6.npy',
#  'trial_2_6.npy',
#  'trial_3_6.npy',
#  'trial_0_7.npy',
#  'trial_1_7.npy',
#  'trial_2_7.npy',
#  'trial_3_7.npy',
#  'trial_0_8.npy',
#  'trial_1_8.npy',
#  'trial_2_8.npy',
#  'trial_3_8.npy',
#  'trial_0_9.npy',
#  'trial_1_9.npy',
#  'trial_2_9.npy',
#  'trial_3_9.npy',
#  'trial_0_10.npy',
#  'trial_1_10.npy',
#  'trial_2_10.npy',
#  'trial_3_10.npy',
#  'trial_0_11.npy',
#  'trial_1_11.npy',
#  'trial_2_11.npy',
#  'trial_3_11.npy',
#  'trial_0_12.npy',
#  'trial_1_12.npy',
#  'trial_2_12.npy',
#  'trial_3_12.npy',
#  'trial_0_13.npy',
#  'trial_1_13.npy',
#  'trial_2_13.npy',
#  'trial_3_13.npy',
#  'trial_0_14.npy',
#  'trial_1_14.npy',
#  'trial_2_14.npy',
#  'trial_3_14.npy',
#  'trial_0_15.npy',
#  'trial_1_15.npy',
#  'trial_2_15.npy',
#  'trial_3_15.npy',
#  'trial_0_16.npy',
#  'trial_1_16.npy',
#  'trial_2_16.npy',
#  'trial_3_16.npy',
#  'trial_0_17.npy',
#  'trial_1_17.npy',
#  'trial_2_17.npy',
#  'trial_3_17.npy',
#  'trial_0_18.npy',
#  'trial_1_18.npy',
#  'trial_2_18.npy',
#  'trial_3_18.npy',
#  'trial_0_19.npy',
#  'trial_1_19.npy',
#  'trial_2_19.npy',
#  'trial_3_19.npy',
#  'trial_0_20.npy',
#  'trial_1_20.npy',
#  'trial_2_20.npy',
#  'trial_3_20.npy',
#  'trial_0_21.npy',
#  'trial_1_21.npy',
#  'trial_2_21.npy',
#  'trial_3_21.npy',
#  'trial_0_22.npy',
#  'trial_1_22.npy',
#  'trial_2_22.npy',
#  'trial_3_22.npy',
#  'trial_0_23.npy',
#  'trial_1_23.npy',
#  'trial_2_23.npy',
#  'trial_3_23.npy']

# %%
Acc = []
Pre = []
Rec = []
F1 = []
Jac = []
for i in range(0,96):
    a = np.load(path_image+image_list[i])
    b = np.load(path_mask+image_list[i])
    actual =(b[0])
    plt.figure()
    plt.title('original')
    plt.imshow(actual)
    plt.show()
    
    predict =(a[0]>0.5)*1
    plt.title('new')
    plt.imshow(predict,cmap="gray")
    plt.show()
    
    
    accuracy = np.sum((actual==predict)*1)/512/512*100
    print('Accuracy =',accuracy,'%')
    
    Jac.append(jaccard_score(actual.flatten(), predict.flatten(),average = 'binary'))
    
    precision, recall, F1score, support = precision_recall_fscore_support(actual.flatten(), predict.flatten(),average = 'binary')
    
    Acc.append(accuracy)
    Pre.append(precision)
    Rec.append(recall)
    F1.append(F1score)
    
    print('**********************')
# Out:
# Accuracy = 96.70906066894531 %
# **********************
# Accuracy = 86.10267639160156 %
# **********************
# Accuracy = 92.61550903320312 %
# **********************
# Accuracy = 97.3114013671875 %
# **********************
# Accuracy = 89.51416015625 %
# **********************
# Accuracy = 92.02919006347656 %
# **********************
# Accuracy = 89.63890075683594 %
# **********************
# Accuracy = 97.36061096191406 %
# **********************
# Accuracy = 94.96307373046875 %
# **********************
# Accuracy = 97.15995788574219 %
# **********************
# Accuracy = 96.89102172851562 %
# **********************
# Accuracy = 95.93658447265625 %
# **********************
# Accuracy = 95.9930419921875 %
# **********************
# Accuracy = 95.23239135742188 %
# **********************
# Accuracy = 94.26422119140625 %
# **********************
# Accuracy = 95.43647766113281 %
# **********************
# Accuracy = 93.04084777832031 %
# **********************
# Accuracy = 90.71083068847656 %
# **********************
# Accuracy = 90.76423645019531 %
# **********************
# Accuracy = 97.68714904785156 %
# **********************
# Accuracy = 97.00546264648438 %
# **********************
# Accuracy = 95.88203430175781 %
# **********************
# Accuracy = 95.90377807617188 %
# **********************
# Accuracy = 95.76950073242188 %
# **********************
# Accuracy = 90.28701782226562 %
# **********************
# Accuracy = 90.19203186035156 %
# **********************
# Accuracy = 90.18096923828125 %
# **********************
# Accuracy = 90.10658264160156 %
# **********************
# Accuracy = 94.50836181640625 %
# **********************
# Accuracy = 90.15083312988281 %
# **********************
# Accuracy = 84.95407104492188 %
# **********************
# Accuracy = 97.540283203125 %
# **********************
# Accuracy = 90.625 %
# **********************
# Accuracy = 89.67437744140625 %
# **********************
# Accuracy = 90.47431945800781 %
# **********************
# Accuracy = 96.39129638671875 %
# **********************
# Accuracy = 93.25981140136719 %
# **********************
# Accuracy = 93.17207336425781 %
# **********************
# Accuracy = 97.65853881835938 %
# **********************
# Accuracy = 96.24061584472656 %
# **********************
# Accuracy = 91.91970825195312 %
# **********************
# Accuracy = 86.57608032226562 %
# **********************
# Accuracy = 94.16694641113281 %
# **********************
# Accuracy = 96.36192321777344 %
# **********************
# Accuracy = 91.54167175292969 %
# **********************
# Accuracy = 87.8082275390625 %
# **********************
# Accuracy = 95.96138000488281 %
# **********************
# Accuracy = 97.62916564941406 %
# **********************
# Accuracy = 90.65361022949219 %
# **********************
# Accuracy = 97.00355529785156 %
# **********************
# Accuracy = 92.60406494140625 %
# **********************
# Accuracy = 96.54998779296875 %
# **********************
# Accuracy = 87.66326904296875 %
# **********************
# Accuracy = 94.86427307128906 %
# **********************
# Accuracy = 94.86770629882812 %
# **********************
# Accuracy = 92.56973266601562 %
# **********************
# Accuracy = 80.57022094726562 %
# **********************
# Accuracy = 93.78623962402344 %
# **********************
# Accuracy = 86.80419921875 %
# **********************
# Accuracy = 93.91250610351562 %
# **********************
# Accuracy = 94.63119506835938 %
# **********************
# Accuracy = 96.85325622558594 %
# **********************
# Accuracy = 93.61038208007812 %
# **********************
# Accuracy = 96.20018005371094 %
# **********************
# Accuracy = 94.31571960449219 %
# **********************
# Accuracy = 93.73016357421875 %
# **********************
# Accuracy = 87.87155151367188 %
# **********************
# Accuracy = 93.16749572753906 %
# **********************
# Accuracy = 94.7509765625 %
# **********************
# Accuracy = 97.51434326171875 %
# **********************
# Accuracy = 94.79637145996094 %
# **********************
# Accuracy = 96.19407653808594 %
# **********************
# Accuracy = 93.85948181152344 %
# **********************
# Accuracy = 92.37442016601562 %
# **********************
# Accuracy = 94.38247680664062 %
# **********************
# Accuracy = 94.37103271484375 %
# **********************
# Accuracy = 98.07586669921875 %
# **********************
# Accuracy = 99.39117431640625 %
# **********************
# Accuracy = 89.51988220214844 %
# **********************
# Accuracy = 95.47195434570312 %
# **********************
# Accuracy = 92.16270446777344 %
# **********************
# Accuracy = 97.2137451171875 %
# **********************
# Accuracy = 96.18377685546875 %
# **********************
# Accuracy = 96.87652587890625 %
# **********************
# Accuracy = 96.1456298828125 %
# **********************
# Accuracy = 98.18763732910156 %
# **********************
# Accuracy = 92.31643676757812 %
# **********************
# Accuracy = 92.35267639160156 %
# **********************
# Accuracy = 97.23396301269531 %
# **********************
# Accuracy = 84.12818908691406 %
# **********************
# Accuracy = 90.42930603027344 %
# **********************
# Accuracy = 97.26715087890625 %
# **********************
# Accuracy = 97.60284423828125 %
# **********************
# Accuracy = 96.08612060546875 %
# **********************
# Accuracy = 95.86982727050781 %
# **********************
# Accuracy = 97.78022766113281 %
# **********************

# %%
np.mean(Acc)
# Out:
# 93.66741180419922

# %%
np.mean(Pre)
# Out:
# 0.7927226827849091

# %%
np.mean(F1)
# Out:
# 0.7653491046143147

# %%
np.mean(recall)
# Out:
# 0.9375564443297639

# %%
np.mean(Jac)
# Out:
# 0.6411513012166267

# %%
np.median(Acc)
# Out:
# 94.44541931152344

# %%
np.median(Jac)
# Out:
# 0.6971725201420836
